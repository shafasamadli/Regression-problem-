# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/ACER/Downloads/binaaz_train.csv/binaaz_train.csv")
df
# Out:
#           _id                                              title   price  \
# 0           6    Satılır 3 otaqlı yeni tikili 135 m², Gənclik m.  300000
# 1          22  Satılır 3 otaqlı yeni tikili 132.5 m², Nəriman...  153000
# 2          72      Satılır 2 otaqlı yeni tikili 115 m², Bayıl q.  171300
# 3          76     Satılır 2 otaqlı yeni tikili 43 m², Masazır q.   44500
# 4          86  Satılır 2 otaqlı yeni tikili 65 m², Memar Əcəm...   89900
# ...       ...                                                ...     ...
# 69310  147185     Satılır 4 otaqlı yeni tikili 220 m², Nəsimi r.  550000
# 69311  147186  Satılır 2 otaqlı yeni tikili 68 m², Nəriman Nə...  177000
# 69312  147187       Satılır 2 otaqlı yeni tikili 72 m², Xırdalan   46000
# 69313  147189      Satılır 3 otaqlı yeni tikili 109 m², Xırdalan  109000
# 69314  147190       Satılır 2 otaqlı yeni tikili 82 m², Xırdalan   74000
#
#       price_currency         poster       poster_type  \
# ...

# %%
dict1 = dict(df.description.str.split(expand=True).stack().value_counts())

# %%
dict1
# Out:
# {'və': 67247,
#  '2': 45498,
#  '3': 36096,
#  'mənzil': 32543,
#  'var.': 29096,
#  'olan': 24630,
#  ',': 21576,
#  'yeni': 21569,
#  'menzil': 21221,
#  'satılır.': 20594,
#  'mərtəbəli': 20516,
#  've': 19892,
#  '-': 19826,
#  'sahəsi': 17822,
#  'üçün': 17302,
#  'binanın': 17075,
#  '1': 16732,
#  'otaqlı': 16030,
#  'и': 15621,
#  'ilə': 15462,
#  'mərtəbəsində': 15235,
#  '24': 14427,
#  'saat': 14415,
#  'tikili': 14146,
#  'sistemi': 14077,
#  'var': 13918,
#  'tam': 13908,
#  'yaşayış': 13835,
#  'Mənzil': 13462,
#  '.': 13104,
#  'təmirli': 12823,
#  'geniş': 12737,
#  '4': 12169,
#  'в': 11521,
#  'binanin': 11310,
#  'otaqli': 10965,
#  'Bina': 10848,
#  'kv': 10724,
#  'Yeni': 10285,
#  '!!!': 10270,
#  'uşaq': 10203,
#  'binada': 10074,
#  'mertebesinde': 10059,
#  'с': 10016,
#  'mertebeli': 9874,
#  'bir': 9636,
#  'su': 9434,
#  'Binanın': 9409,
#  'Binada': 9361,
#  'Mənzilin': 9348,
#  'temirli': 9012,
#  '!': 8687,
#  'ucun': 8578,
#  'çox': 8362,
# ...

# %%
# https://www.kaggle.com/code/eraaz1/a-comprehensive-guide-to-titanic-machine-learning#10.Data-Transformation-

# %%
df["Kupça"]=df["Kupça"].fillna("var")

# %%
df['Kupça'] = df['Kupça'].astype('category')
df['Kupça'] = df['Kupça'].cat.codes
df['Kupça']
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        0
#         ..
# 69310    0
# 69311    1
# 69312    1
# 69313    1
# 69314    1
# Name: Kupça, Length: 69315, dtype: int8

# %%
df['poster_type'] = df['poster_type'].astype('category')
df['poster_type'] = df['poster_type'].cat.codes
df['poster_type']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 69310    1
# 69311    1
# 69312    1
# 69313    1
# 69314    1
# Name: poster_type, Length: 69315, dtype: int8

# %%
df['İpoteka'] = df['İpoteka'].astype('category')
df['İpoteka'] = df['İpoteka'].cat.codes
df['İpoteka']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 69310    1
# 69311    1
# 69312    1
# 69313    1
# 69314    1
# Name: İpoteka, Length: 69315, dtype: int8

# %%
df['seher'] = df['seher'].astype('category')
df['seher'] = df['seher'].cat.codes
df['seher']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 69310    0
# 69311    0
# 69312    2
# 69313    2
# 69314    2
# Name: seher, Length: 69315, dtype: int8

# %%
df["Sahə"] = df["Sahə"].str.replace("m²","")
df["Sahə"] = df["Sahə"].str.replace("м²","")
df["Sahə"]=df["Sahə"].apply(lambda x:float(x))

# %% [raw]
# Q1 = df["price"].quantile(q=0.25)
# Q3 = df["price"].quantile(q=0.75)
# IQR = Q3-Q1
# # remove outliers
# ul = Q3 + 1.5 * IQR
# ll = Q1 - 1.5*IQR
# outliers = [(df["price"] > ul) | (df["price"] < ll)]
# df.drop(df[(df.price > ul) | (df.price < ll) ].index , inplace=True)

# %% [raw]
# Q1 = df["Sahə"].quantile(q=0.25)
# Q3 = df["Sahə"].quantile(q=0.75)
# IQR = Q3-Q1
# # remove outliers
# ul = Q3 + 1.5 * IQR
# ll = Q1 - 1.5*IQR
# outliers = [(df["Sahə"] > ul) | (df["Sahə"] < ll)]
# df.drop(df[(df.Sahə > ul) | (df.Sahə < ll) ].index , inplace=True)

# %% [raw]
# Q1 = df["price_for_per_metre"].quantile(q=0.25)
# Q3 = df["price_for_per_metre"].quantile(q=0.75)
# IQR = Q3-Q1
# # remove outliers
# ul = Q3 + 1.5 * IQR
# ll = Q1 - 1.5*IQR
# outliers = [(df["price_for_per_metre"] > ul) | (df["price_for_per_metre"] < ll)]
# df.drop(df[(df.price_for_per_metre > ul) | (df.price_for_per_metre < ll) ].index , inplace=True)

# %% [raw]
# Q1 = df["latitude"].quantile(q=0.25)
# Q3 = df["latitude"].quantile(q=0.75)
# IQR = Q3-Q1
# # remove outliers
# ul = Q3 + 1.5 * IQR
# ll = Q1 - 1.5*IQR
# outliers = [(df["latitude"] > ul) | (df["latitude"] < ll)]
# df.drop(df[(df.latitude > ul) | (df.latitude < ll) ].index , inplace=True)

# %% [raw]
# Q1 = df["longitude"].quantile(q=0.25)
# Q3 = df["longitude"].quantile(q=0.75)
# IQR = Q3-Q1
# # remove outliers
# ul = Q3 + 1.5 * IQR
# ll = Q1 - 1.5*IQR
# outliers = [(df["longitude"] > ul) | (df["longitude"] < ll)]
# df.drop(df[(df.longitude > ul) | (df.longitude < ll) ].index , inplace=True)

# %%
df.columns
# Out:
# Index(['_id', 'title', 'price', 'price_currency', 'poster', 'poster_type',
#        'Ünvan', 'description', 'Yeniləndi', 'Mərtəbə', 'Sahə', 'Otaq sayı',
#        'Kupça', 'İpoteka', 'locations', 'latitude', 'longitude', 'seher'],
#       dtype='object')

# %%
df = df[(df['Sahə']>10)&(df['Sahə']<1000)]
df = df[df['Otaq sayı']<15]
df = df[(df['price']>5000)&(df['price']<3000000)]
df = df[(df['price']/df['Sahə']>200)&(df['price']/df['Sahə']<4000)]
df = df[(df['Sahə']/df['Otaq sayı']>5)&(df['Sahə']/df['Otaq sayı']<100)]

# %%
df['Mərtəbə'] = df['Mərtəbə'].apply(lambda x: int(x.split('/')[0])/int(x.split('/')[1]))

# %%
df['urg'] = df['description'].apply(lambda x: any([w in str(x).lower() for w in ['tecili', 'təcili', 'tacili', 'tcili', 'təcılı']]))

# %%
df["new_features"] = df['description'].apply(lambda x: any([w in str(x).lower() for w in ['premium', 'Premium', 'vip', 'Vip', 'VIP','super','Super','yuksek','Yüksək','yüksək','temirli','Temirli','Təmirli','təmirli','luks','Luks','lüks','Lüks']]))

# %%
df['urg'] = df['urg'].astype('category')
df['urg'] = df['urg'].cat.codes
df['urg']
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 69310    0
# 69311    1
# 69312    0
# 69313    0
# 69314    0
# Name: urg, Length: 68267, dtype: int8

# %%
df['new_features'] = df['new_features'].astype('category')
df['new_features'] = df['new_features'].cat.codes
df['new_features']
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 69310    1
# 69311    1
# 69312    0
# 69313    1
# 69314    1
# Name: new_features, Length: 68267, dtype: int8

# %%
features = ["Mərtəbə",'Sahə','Otaq sayı','Kupça','İpoteka','seher',"urg","new_features"]

# %%
X = df[features]

# %%
pip install mlxtend
# Out:
# ...
#
#   Using cached mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
# ...

# %%
df_test = pd.read_csv("C:/Users/ACER/Downloads/binaaz_test.csv/binaaz_test.csv")
df_test
# Out:
#           _id                                              title  \
# 0       20886   Satılır 1 otaqlı yeni tikili 50.4 m², Koroğlu m.
# 1      117465    Satılır 3 otaqlı yeni tikili 98 m², Badamdar q.
# 2      125220    Satılır 5 otaqlı yeni tikili 205 m², Yasamal r.
# 3       77683  Satılır 3 otaqlı yeni tikili 117 m², Yeni Yasa...
# 4       77672     Satılır 4 otaqlı yeni tikili 227 m², Nəsimi r.
# ...       ...                                                ...
# 19995  145960  Satılır 3 otaqlı yeni tikili 117 m², Azadlıq P...
# 19996   66440     Satılır 3 otaqlı yeni tikili 120 m², Nizami m.
# 19997   29047  Satılır 2 otaqlı yeni tikili 60 m², 9-cu mikro...
# 19998   81762      Satılır 4 otaqlı yeni tikili 143 m², Xətai r.
# 19999  137332      Satılır 1 otaqlı yeni tikili 50 m², Nəsimi r.
#
#       price_currency     poster       poster_type  \
# 0                AZN      Feqan  vasitəçi (agent)
# 1                AZN   Baloğlan       mülkiyyətçi
# ...

# %%
df_test['urg'] = df_test['description'].apply(lambda x: any([w in str(x).lower() for w in ['tecili', 'təcili', 'tacili', 'tcili', 'təcılı']]))
df_test["new_features"] = df_test['description'].apply(lambda x: any([w in str(x).lower() for w in ['premium', 'Premium', 'vip', 'Vip', 'VIP','super','Super','yuksek','Yüksək','yüksək','temirli','Temirli','Təmirli','təmirli','luks','Luks','lüks','Lüks']]))

# %%
df_test['new_features'] = df_test['new_features'].astype('category')
df_test['new_features'] = df_test['new_features'].cat.codes
df_test['new_features']
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 19995    0
# 19996    0
# 19997    1
# 19998    0
# 19999    1
# Name: new_features, Length: 20000, dtype: int8

# %%
df_test['urg'] = df_test['urg'].astype('category')
df_test['urg'] = df_test['urg'].cat.codes
df_test['urg']
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 19995    1
# 19996    1
# 19997    1
# 19998    1
# 19999    0
# Name: urg, Length: 20000, dtype: int8

# %%
df_test["Kupça"]=df["Kupça"].fillna("var")

# %%
df_test['Kupça'] = df_test['Kupça'].astype('category')
df_test['Kupça'] = df_test['Kupça'].cat.codes
df_test['Kupça']
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        0
#         ..
# 19995    0
# 19996    1
# 19997    0
# 19998    0
# 19999    0
# Name: Kupça, Length: 20000, dtype: int8

# %%
df_test['poster_type'] = df_test['poster_type'].astype('category')
df_test['poster_type'] = df_test['poster_type'].cat.codes
df_test['poster_type']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 19995    1
# 19996    1
# 19997    1
# 19998    1
# 19999    1
# Name: poster_type, Length: 20000, dtype: int8

# %%
df_test['İpoteka'] = df_test['İpoteka'].astype('category')
df_test['İpoteka'] = df_test['İpoteka'].cat.codes
df_test['İpoteka']
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 19995    1
# 19996    1
# 19997    1
# 19998    0
# 19999    1
# Name: İpoteka, Length: 20000, dtype: int8

# %%
df_test['seher'] = df_test['seher'].astype('category')
df_test['seher'] = df_test['seher'].cat.codes
df_test['seher']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 19995    0
# 19996    0
# 19997    0
# 19998    0
# 19999    0
# Name: seher, Length: 20000, dtype: int8

# %%
df_test["Sahə"] = df_test["Sahə"].str.replace("m²","")
df_test["Sahə"] = df_test["Sahə"].str.replace("м²","")
df_test["Sahə"]=df_test["Sahə"].apply(lambda x:float(x))

# %%
df_test['Mərtəbə'] = df_test['Mərtəbə'].apply(lambda x: int(x.split('/')[0])/int(x.split('/')[1]))

# %%
X
# Out:
#         Mərtəbə   Sahə  Otaq sayı  Kupça  İpoteka  seher  urg  new_features
# 0      0.294118  135.0          3      0        1      0    1             1
# 1      0.625000  132.5          3      1        1      0    0             0
# 2      0.500000  115.0          2      1        1      0    1             0
# 3      0.500000   43.0          2      0        1      0    0             1
# 4      0.666667   65.0          2      0        1      0    1             1
# ...         ...    ...        ...    ...      ...    ...  ...           ...
# 69310  1.000000  220.0          4      0        1      0    0             1
# 69311  0.647059   68.0          2      1        1      0    1             1
# 69312  1.000000   72.0          2      1        1      2    0             0
# 69313  0.571429  109.0          3      1        1      2    0             1
# 69314  0.812500   82.0          2      1        1      2    0             1
#
# [68267 rows x 8 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
Y = df['price']
seed = 7
test_size = 20000
X_train = df[features]
X_test = df_test[features]
y_train = Y

# %%
from xgboost import XGBRegressor
model_xgb = XGBRegressor()
model_xgb.fit(X_train, y_train)
y_pred_xgb = model_xgb.predict(X_test)

# %%
submission_xgb_last1 = pd.DataFrame(df_test["_id"])
submission_xgb_last1
# Out:
#           _id
# 0       20886
# 1      117465
# 2      125220
# 3       77683
# 4       77672
# ...       ...
# 19995  145960
# 19996   66440
# 19997   29047
# 19998   81762
# 19999  137332
#
# [20000 rows x 1 columns]

# %%
submission_xgb_last1["price"]=y_pred_xgb

# %%
submission_xgb_last1.to_csv(r'C:\Users\ACER\Downloads/submission_xgb_last11.csv', index = False, header=True)

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest = RandomForestRegressor(n_estimators=100)
random_forest.fit(X_train, y_train)
y_pred_rf = random_forest.predict(X_test)
random_forest.score(X_train, y_train)
acc_random_forest = round(random_forest.score(X_train, y_train) * 100, 2)
acc_random_forest
# Out:
# 95.62

# %%
submission_rf_last = pd.DataFrame(df_test["_id"])
submission_rf_last
# Out:
#           _id
# 0       20886
# 1      117465
# 2      125220
# 3       77683
# 4       77672
# ...       ...
# 19995  145960
# 19996   66440
# 19997   29047
# 19998   81762
# 19999  137332
#
# [20000 rows x 1 columns]

# %%
submission_rf_last["price"]=y_pred_rf

# %%
submission_rf_last.to_csv(r'C:\Users\ACER\Downloads/submission_rf_last12.csv', index = False, header=True)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
rf = RandomForestRegressor(random_state = 1)
param_grid = {
    'bootstrap': [True,False],
    'max_depth': [80,100,120,140,150],
    'n_estimators': [200,400,600,800,900]
}

# %%
x = df[features]
y = df['price']

# %%
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 5)
grid_search.fit(x,y)

# %%
grid_search.best_params_

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(max_depth = 100, n_estimators=900,random_state=1)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
y_pred.shape
# Out:
# (20000,)

# %%
submission_rf_last1 = pd.DataFrame(df_test["_id"])
submission_rf_last1
# Out:
#           _id
# 0       20886
# 1      117465
# 2      125220
# 3       77683
# 4       77672
# ...       ...
# 19995  145960
# 19996   66440
# 19997   29047
# 19998   81762
# 19999  137332
#
# [20000 rows x 1 columns]

# %%
submission_rf_last1["price"]=y_pred

# %%
submission_rf_last1.to_csv(r'C:\Users\ACER\Downloads/submission_rf_last7.csv', index = False, header=True)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
rnd_clf = RandomForestRegressor()
model_lr = LinearRegression()
xgb_model = XGBRegressor()
voting_clf = VotingRegressor(estimators=[('rf', rnd_clf),('xgb',xgb_model),("lr_model",model_lr)])
voting_clf = VotingRegressor(
estimators=[('model_lr', model_lr), ('rnd_clf', rnd_clf), ('xgb', xgb_model)])
voting_clf.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('model_lr', LinearRegression()),
#                             ('rnd_clf', RandomForestRegressor()),
#                             ('xgb',
#                              XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, gamma=None,
#                                           gpu_id=None, grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
# ...

# %%
from sklearn.metrics import accuracy_score
for clf in (model_lr, rnd_clf, xgb_model, voting_clf):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

# %%
y_pred.shape
# Out:
# (20000,)

# %%
submission_rf_last1 = pd.DataFrame(df_test["_id"])
submission_rf_last1
# Out:
#           _id
# 0       20886
# 1      117465
# 2      125220
# 3       77683
# 4       77672
# ...       ...
# 19995  145960
# 19996   66440
# 19997   29047
# 19998   81762
# 19999  137332
#
# [20000 rows x 1 columns]

# %%
submission_rf_last1["price"]=y_pred

# %%
submission_rf_last1.to_csv(r'C:\Users\ACER\Downloads/submission_rf_last9.csv', index = False, header=True)

# %%
xgb1 = XGBRegressor()
parameters = {
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [1,2,3,4],
              'n_estimators': [200,400,600,800]}

xgb_grid = GridSearchCV(xgb1,
                        parameters,
                        cv = 5,
                        n_jobs = 5,
                        verbose=True)

xgb_grid.fit(X_train,y_train)

print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
